# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
data = pd.read_csv(r'C:\Users\jatin\Desktop\dlProject\new\cs-training.csv')

# Handle missing values
data = data.fillna(0)  # Replace missing values with 0 for simplicity

# Split the dataset into features and labels
X_train = data.drop(columns=['SeriousDlqin2yrs'])
y_train = data['SeriousDlqin2yrs']

datat = pd.read_csv(r'C:\Users\jatin\Desktop\dlProject\new\cs-test.csv')

# Handle missing values
datat = datat.fillna(0)  # Replace missing values with 0 for simplicity

# Split the dataset into features and labels
X_test = data.drop(columns=['SeriousDlqin2yrs'])
y_test = data['SeriousDlqin2yrs']

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Now X_train_scaled and X_test_scaled are the preprocessed feature sets
# y_train and y_test are the corresponding labels

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Define the neural network architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))  # Binary classification output

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Display the model summary
model.summary()

# Train the model
history = model.fit(X_train_scaled, y_train, epochs=20, batch_size=32, validation_split=0.1)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Accuracy:", test_accuracy)

# Save the trained model
model.save('credit_scoring_model.h5')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 64)                768
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 4219/4219 [==============================] - 5s 998us/step - loss: 0.2010 - accuracy: 0.9341 - val_loss: 0.1955 - val_accuracy: 0.9335
# Epoch 2/20
# 4219/4219 [==============================] - 4s 960us/step - loss: 0.1896 - accuracy: 0.9364 - val_loss: 0.1939 - val_accuracy: 0.9333
# Epoch 3/20
# 4219/4219 [==============================] - 4s 984us/step - loss: 0.1882 - accuracy: 0.9368 - val_loss: 0.1957 - val_accuracy: 0.9319
# Epoch 4/20
# 4219/4219 [==============================] - 4s 957us/step - loss: 0.1878 - accuracy: 0.9367 - val_loss: 0.1923 - val_accuracy: 0.9344
# Epoch 5/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1871 - accuracy: 0.9369 - val_loss: 0.1948 - val_accuracy: 0.9329
# Epoch 6/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1870 - accuracy: 0.9370 - val_loss: 0.1921 - val_accuracy: 0.9341
# Epoch 7/20
# 4219/4219 [==============================] - 4s 957us/step - loss: 0.1867 - accuracy: 0.9371 - val_loss: 0.1931 - val_accuracy: 0.9330
# Epoch 8/20
# 4219/4219 [==============================] - 4s 964us/step - loss: 0.1864 - accuracy: 0.9372 - val_loss: 0.1935 - val_accuracy: 0.9335
# Epoch 9/20
# 4219/4219 [==============================] - 4s 955us/step - loss: 0.1861 - accuracy: 0.9374 - val_loss: 0.1932 - val_accuracy: 0.9324
# Epoch 10/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1860 - accuracy: 0.9376 - val_loss: 0.1928 - val_accuracy: 0.9329
# Epoch 11/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1856 - accuracy: 0.9374 - val_loss: 0.1930 - val_accuracy: 0.9323
# Epoch 12/20
# 4219/4219 [==============================] - 4s 965us/step - loss: 0.1856 - accuracy: 0.9376 - val_loss: 0.1922 - val_accuracy: 0.9325
# Epoch 13/20
# 4219/4219 [==============================] - 4s 965us/step - loss: 0.1854 - accuracy: 0.9378 - val_loss: 0.1915 - val_accuracy: 0.9329
# Epoch 14/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1852 - accuracy: 0.9377 - val_loss: 0.1910 - val_accuracy: 0.9329
# Epoch 15/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1851 - accuracy: 0.9375 - val_loss: 0.1924 - val_accuracy: 0.9326
# Epoch 16/20
# 4219/4219 [==============================] - 4s 972us/step - loss: 0.1849 - accuracy: 0.9376 - val_loss: 0.1937 - val_accuracy: 0.9322
# Epoch 17/20
# 4219/4219 [==============================] - 4s 963us/step - loss: 0.1848 - accuracy: 0.9377 - val_loss: 0.1924 - val_accuracy: 0.9326
# Epoch 18/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1846 - accuracy: 0.9379 - val_loss: 0.1913 - val_accuracy: 0.9332
# Epoch 19/20
# 4219/4219 [==============================] - 4s 957us/step - loss: 0.1845 - accuracy: 0.9379 - val_loss: 0.1927 - val_accuracy: 0.9327
# Epoch 20/20
# 4219/4219 [==============================] - 4s 1ms/step - loss: 0.1843 - accuracy: 0.9382 - val_loss: 0.1928 - val_accuracy: 0.9326
# 4688/4688 [==============================] - 4s 792us/step - loss: 0.1845 - accuracy: 0.9380
# Test Accuracy: 0.938040018081665

# %%
import matplotlib.pyplot as plt

# Access training history
training_accuracy = minimal_history.history['accuracy']
validation_accuracy = minimal_history.history['val_accuracy']
training_loss = minimal_history.history['loss']
validation_loss = minimal_history.history['val_loss']

# Plot training and validation accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

# Make predictions on the test set
y_pred_probs = model.predict(X_test_scaled)
y_pred = (y_pred_probs > 0.5).astype(int)

# Display classification report and confusion matrix
print(classification_report(y_test, y_pred))
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

from sklearn.metrics import confusion_matrix, classification_report, f1_score
import seaborn as sns

# Make predictions on the test set
minimal_y_pred = minimal_model.predict_classes(X_test_scaled)

# Confusion Matrix
conf_matrix = confusion_matrix(y_test, minimal_y_pred)
plt.figure(figsize=(6, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()

# Classification Report
print("Classification Report:")
print(classification_report(y_test, minimal_y_pred))

# F1-Score Curve
f1_scores = []
thresholds = np.arange(0.2, 1.0, 0.05)
for threshold in thresholds:
    y_pred_thresholded = (minimal_y_pred_probs > threshold).astype(int)
    f1 = f1_score(y_test, y_pred_thresholded)
    f1_scores.append(f1)

plt.figure(figsize=(8, 5))
plt.plot(thresholds, f1_scores, marker='o')
plt.xlabel('Threshold')
plt.ylabel('F1-Score')
plt.title('F1-Score Curve')
plt.grid()
plt.show()
# Out:
# 4688/4688 [==============================] - 3s 741us/step - loss: 0.1845 - accuracy: 0.9380
# Test Loss: 0.184544175863266
# Test Accuracy: 0.938040018081665
# 4688/4688 [==============================] - 3s 630us/step
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97    139974
#            1       0.61      0.20      0.30     10026
#
#     accuracy                           0.94    150000
#    macro avg       0.78      0.60      0.64    150000
# weighted avg       0.92      0.94      0.92    150000
#
# Confusion Matrix:
# [[138685   1289]
#  [  8005   2021]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 23
#      20 import seaborn as sns
#      22 # Make predictions on the test set
# ---> 23 minimal_y_pred = minimal_model.predict_classes(X_test_scaled)
#      25 # Confusion Matrix
#      26 conf_matrix = confusion_matrix(y_test, minimal_y_pred)
#
# AttributeError: 'Sequential' object has no attribute 'predict_classes'

# %%
TRYING OTHER TYPES OF ANN models

# %%
#slight complex model
from tensorflow.keras.layers import Dropout
from tensorflow.keras.callbacks import LearningRateScheduler, EarlyStopping

# Define the neural network architecture with dropout
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dropout(0.5))  # Adding dropout layer
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Define a learning rate schedule
def lr_schedule(epoch):
    learning_rate = 0.001
    if epoch > 10:
        learning_rate = 0.0001
    return learning_rate

# Learning rate scheduler callback
lr_scheduler = LearningRateScheduler(lr_schedule)

# Early stopping callback
early_stopping = EarlyStopping(patience=5, restore_best_weights=True)

# Train the model with callbacks
history = model.fit(X_train_scaled, y_train, epochs=30, batch_size=32,
                    validation_split=0.1, callbacks=[lr_scheduler, early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/30
# 1356/4219 [========>.....................] - ETA: 2s - loss: 0.2340 - accuracy: 0.9335
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 28
#      25 early_stopping = EarlyStopping(patience=5, restore_best_weights=True)
#      27 # Train the model with callbacks
# ---> 28 history = model.fit(X_train_scaled, y_train, epochs=30, batch_size=32,
#      29                     validation_split=0.1, callbacks=[lr_scheduler, early_stopping])
#      31 # Evaluate the model on the test set
#      32 test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\training.py:1676, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1674 callbacks.on_epoch_begin(epoch)
#    1675 with data_handler.catch_stop_iteration():
# -> 1676     for step in data_handler.steps():
#    1677         with tf.profiler.experimental.Trace(
#    1678             "train",
#    1679             epoch_num=epoch,
#    (...)
#    1682             _r=1,
#    1683         ):
#    1684             callbacks.on_train_batch_begin(step)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\engine\data_adapter.py:1375, in DataHandler.steps(self)
#    1373 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1374     break
# -> 1375 original_spe = self._steps_per_execution.numpy().item()
#    1376 can_run_full_execution = (
#    1377     original_spe == 1
#    1378     or self._inferred_steps is None
#    1379     or self._inferred_steps - self._current_step >= original_spe
#    1380 )
#    1382 if can_run_full_execution:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:647, in BaseResourceVariable.numpy(self)
#     645 def numpy(self):
#     646   if context.executing_eagerly():
# --> 647     return self.read_value().numpy()
#     648   raise NotImplementedError(
#     649       "numpy() is only available when eager execution is enabled.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:774, in BaseResourceVariable.read_value(self)
#     765 """Constructs an op which reads the value of this variable.
#     766
#     767 Should be used when there are multiple reads, or when it is desirable to
#    (...)
#     771   The value of the variable.
#     772 """
#     773 with ops.name_scope("Read"):
# --> 774   value = self._read_variable_op()
#     775 # Return an identity so it can get placed on whatever device the context
#     776 # specifies instead of the device where the variable is.
#     777 return array_ops.identity(value)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:753, in BaseResourceVariable._read_variable_op(self, no_copy)
#     751       result = read_and_set_handle(no_copy)
#     752 else:
# --> 753   result = read_and_set_handle(no_copy)
#     755 if not context.executing_eagerly():
#     756   # Note that if a control flow context is active the input of the read op
#     757   # might not actually be the handle. This line bypasses it.
#     758   tape.record_operation(
#     759       "ReadVariableOp", [result], [self.handle],
#     760       backward_function=lambda x: [x],
#     761       forward_function=lambda x: [x])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:743, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     741 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     742   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 743 result = gen_resource_variable_ops.read_variable_op(
#     744     self.handle, self._dtype)
#     745 _maybe_set_handle_data(self._dtype, self.handle, result)
#     746 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:580, in read_variable_op(resource, dtype, name)
#     578 if tld.is_eager:
#     579   try:
# --> 580     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     581       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     582     return _result
#     583   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# more complex model
from tensorflow.keras.layers import Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam

# Define a more complex neural network architecture with dropout and batch normalization
model = Sequential()
model.add(Dense(128, activation='relu', input_shape=(X_train_scaled.shape[1],)))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(BatchNormalization())  # Adding batch normalization layer
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model with custom optimizer and learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Define a more aggressive learning rate schedule
def lr_schedule(epoch):
    if epoch < 10:
        return 0.001
    elif epoch < 20:
        return 0.0001
    else:
        return 0.00001

# Learning rate scheduler callback
lr_scheduler = LearningRateScheduler(lr_schedule)

# Early stopping callback
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

# Train the model with callbacks
history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=64,
                    validation_split=0.1, callbacks=[lr_scheduler, early_stopping])

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# Epoch 1/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.2159 - accuracy: 0.9336 - val_loss: 0.2129 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 2/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1977 - accuracy: 0.9348 - val_loss: 0.1994 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 3/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1938 - accuracy: 0.9357 - val_loss: 0.2056 - val_accuracy: 0.9309 - lr: 0.0010
# Epoch 4/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1929 - accuracy: 0.9357 - val_loss: 0.1988 - val_accuracy: 0.9301 - lr: 0.0010
# Epoch 5/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1913 - accuracy: 0.9363 - val_loss: 0.1959 - val_accuracy: 0.9321 - lr: 0.0010
# Epoch 6/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1913 - accuracy: 0.9360 - val_loss: 0.1956 - val_accuracy: 0.9299 - lr: 0.0010
# Epoch 7/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1908 - accuracy: 0.9363 - val_loss: 0.1931 - val_accuracy: 0.9313 - lr: 0.0010
# Epoch 8/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1904 - accuracy: 0.9366 - val_loss: 0.1939 - val_accuracy: 0.9301 - lr: 0.0010
# Epoch 9/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1899 - accuracy: 0.9361 - val_loss: 0.1933 - val_accuracy: 0.9293 - lr: 0.0010
# Epoch 10/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1899 - accuracy: 0.9361 - val_loss: 0.1928 - val_accuracy: 0.9332 - lr: 0.0010
# Epoch 11/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1882 - accuracy: 0.9362 - val_loss: 0.1923 - val_accuracy: 0.9304 - lr: 1.0000e-04
# Epoch 12/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1880 - accuracy: 0.9366 - val_loss: 0.1921 - val_accuracy: 0.9305 - lr: 1.0000e-04
# Epoch 13/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1878 - accuracy: 0.9361 - val_loss: 0.1922 - val_accuracy: 0.9304 - lr: 1.0000e-04
# Epoch 14/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1877 - accuracy: 0.9364 - val_loss: 0.1918 - val_accuracy: 0.9339 - lr: 1.0000e-04
# Epoch 15/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1871 - accuracy: 0.9367 - val_loss: 0.1916 - val_accuracy: 0.9336 - lr: 1.0000e-04
# Epoch 16/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1876 - accuracy: 0.9366 - val_loss: 0.1920 - val_accuracy: 0.9345 - lr: 1.0000e-04
# Epoch 17/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1871 - accuracy: 0.9368 - val_loss: 0.1918 - val_accuracy: 0.9333 - lr: 1.0000e-04
# Epoch 18/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1871 - accuracy: 0.9366 - val_loss: 0.1922 - val_accuracy: 0.9343 - lr: 1.0000e-04
# Epoch 19/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1872 - accuracy: 0.9363 - val_loss: 0.1919 - val_accuracy: 0.9326 - lr: 1.0000e-04
# Epoch 20/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1873 - accuracy: 0.9367 - val_loss: 0.1921 - val_accuracy: 0.9339 - lr: 1.0000e-04
# Epoch 21/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1869 - accuracy: 0.9367 - val_loss: 0.1918 - val_accuracy: 0.9341 - lr: 1.0000e-05
# Epoch 22/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1870 - accuracy: 0.9368 - val_loss: 0.1919 - val_accuracy: 0.9339 - lr: 1.0000e-05
# Epoch 23/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1869 - accuracy: 0.9367 - val_loss: 0.1916 - val_accuracy: 0.9335 - lr: 1.0000e-05
# Epoch 24/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1867 - accuracy: 0.9368 - val_loss: 0.1916 - val_accuracy: 0.9345 - lr: 1.0000e-05
# Epoch 25/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1871 - accuracy: 0.9366 - val_loss: 0.1917 - val_accuracy: 0.9347 - lr: 1.0000e-05
# Epoch 26/50
# 2110/2110 [==============================] - 4s 2ms/step - loss: 0.1869 - accuracy: 0.9364 - val_loss: 0.1918 - val_accuracy: 0.9340 - lr: 1.0000e-05
# Epoch 27/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1868 - accuracy: 0.9365 - val_loss: 0.1917 - val_accuracy: 0.9341 - lr: 1.0000e-05
# Epoch 28/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1869 - accuracy: 0.9364 - val_loss: 0.1918 - val_accuracy: 0.9342 - lr: 1.0000e-05
# Epoch 29/50
# 2110/2110 [==============================] - 3s 2ms/step - loss: 0.1871 - accuracy: 0.9366 - val_loss: 0.1918 - val_accuracy: 0.9331 - lr: 1.0000e-05
# Epoch 30/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1869 - accuracy: 0.9369 - val_loss: 0.1918 - val_accuracy: 0.9339 - lr: 1.0000e-05
# Epoch 31/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1866 - accuracy: 0.9364 - val_loss: 0.1917 - val_accuracy: 0.9339 - lr: 1.0000e-05
# Epoch 32/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1869 - accuracy: 0.9367 - val_loss: 0.1918 - val_accuracy: 0.9343 - lr: 1.0000e-05
# Epoch 33/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1867 - accuracy: 0.9365 - val_loss: 0.1917 - val_accuracy: 0.9340 - lr: 1.0000e-05
# Epoch 34/50
# 2110/2110 [==============================] - 3s 1ms/step - loss: 0.1870 - accuracy: 0.9367 - val_loss: 0.1917 - val_accuracy: 0.9339 - lr: 1.0000e-05
# 4688/4688 [==============================] - 4s 809us/step - loss: 0.1878 - accuracy: 0.9365
# Test Accuracy: 0.9364733099937439

# %%
#very simple mode
# Define a minimal neural network architecture
minimal_model = Sequential()
minimal_model.add(Dense(8, activation='relu', input_shape=(X_train_scaled.shape[1],)))
minimal_model.add(Dense(1, activation='sigmoid'))

# Compile the minimal model
minimal_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the minimal model
minimal_history = minimal_model.fit(X_train_scaled, y_train, epochs=10, batch_size=32,
                                    validation_split=0.1)

# Evaluate the minimal model on the test set
minimal_test_loss, minimal_test_accuracy = minimal_model.evaluate(X_test_scaled, y_test)
print("Minimal Model Test Accuracy:", minimal_test_accuracy)
# Out:
# Epoch 1/10
# 4219/4219 [==============================] - 4s 914us/step - loss: 0.2415 - accuracy: 0.9224 - val_loss: 0.2051 - val_accuracy: 0.9298
# Epoch 2/10
# 4219/4219 [==============================] - 4s 908us/step - loss: 0.1926 - accuracy: 0.9347 - val_loss: 0.1971 - val_accuracy: 0.9301
# Epoch 3/10
# 4219/4219 [==============================] - 4s 915us/step - loss: 0.1907 - accuracy: 0.9353 - val_loss: 0.1957 - val_accuracy: 0.9309
# Epoch 4/10
# 4219/4219 [==============================] - 4s 904us/step - loss: 0.1903 - accuracy: 0.9350 - val_loss: 0.1955 - val_accuracy: 0.9308
# Epoch 5/10
# 4219/4219 [==============================] - 4s 971us/step - loss: 0.1900 - accuracy: 0.9353 - val_loss: 0.1947 - val_accuracy: 0.9310
# Epoch 6/10
# 4219/4219 [==============================] - 4s 936us/step - loss: 0.1898 - accuracy: 0.9355 - val_loss: 0.1945 - val_accuracy: 0.9315
# Epoch 7/10
# 4219/4219 [==============================] - 4s 930us/step - loss: 0.1896 - accuracy: 0.9357 - val_loss: 0.1945 - val_accuracy: 0.9314
# Epoch 8/10
# 4219/4219 [==============================] - 4s 939us/step - loss: 0.1893 - accuracy: 0.9358 - val_loss: 0.1945 - val_accuracy: 0.9315
# Epoch 9/10
# 4219/4219 [==============================] - 4s 915us/step - loss: 0.1893 - accuracy: 0.9356 - val_loss: 0.1934 - val_accuracy: 0.9321
# Epoch 10/10
# 4219/4219 [==============================] - 4s 983us/step - loss: 0.1891 - accuracy: 0.9358 - val_loss: 0.1942 - val_accuracy: 0.9321
# 4688/4688 [==============================] - 4s 794us/step - loss: 0.1897 - accuracy: 0.9355
# Minimal Model Test Accuracy: 0.9355199933052063
